# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import xlsxwriter
import xlrd
from selenium.webdriver.common.keys import Keys
from random import randint
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
import openpyxl
import pandas as pd
from selenium.common.exceptions import TimeoutException
import time

# %%
class Linkedin():
    def getData(self):
        
        #-----------------Linkedin Login------------------------------
        options = webdriver.ChromeOptions()
        options.add_argument("headless")
        driver = webdriver.Chrome('/usr/bin/chromedriver',)
        driver.get('https://www.linkedin.com/login')
        driver.find_element_by_id('username').send_keys('zied2050@gmail.com') #Enter username of linkedin account here
        driver.find_element_by_id('password').send_keys('Zaydounzizou1994')  #Enter Password of linkedin account here
        driver.find_element_by_xpath("//*[@type='submit']").click()
        #-----------------acces to profile page ------------------------
               #------------get data from sheet ---------
        raw_data= xlrd.open_workbook("raw.xlsx").sheet_by_index(0)
        
        global data
        data = []
        
               #-------------open a workbook for data writing --------------
        workbook = xlsxwriter.Workbook("linkedin-search-data.xlsx")
        worksheet = workbook.add_worksheet('Peoples')
        bold = workbook.add_format({'bold': True})
        worksheet.write(0,0,'profile_url',bold)
        worksheet.write(0,1,'Name',bold)
        worksheet.write(0,2,'heading',bold)
        worksheet.write(0,3,'location',bold)
        
        for i in range(2,10):
            company=raw_data.cell_value(i, 25)
            lastname=raw_data.cell_value(i, 26)
            firstname=raw_data.cell_value(i, 27)
            search_url = "https://www.linkedin.com/search/results/people/?company={}&firstName={}&lastName={}&origin=FACETED_SEARCH".format(company,firstname,lastname)
            driver.get(search_url)
            driver.maximize_window()
            time.sleep(2)
            search = BeautifulSoup(driver.page_source,'lxml')
            peoples = search.findAll('a', attrs = {'data-control-name':'search_srp_result'})
            #count = 0
            
            #for people in peoples:
            try:  
                profile_url = "https://www.linkedin.com" + str(peoples[0]['href'])
            except:
                profile_url = 'Not found'
                title = raw_data.cell_value(i, 26)+raw_data.cell_value(i, 27)
                heading = 'Not found'
                loc = 'Not found'
                worksheet.write(i-1,0,profile_url)   
                worksheet.write(i-1,1,title)
                worksheet.write(i-1,2,heading)
                worksheet.write(i-1,3,loc)     
                continue
            driver.get(profile_url)
            # #********** Profile Details **************#
            page = BeautifulSoup(driver.page_source,'lxml')
            try:
                title = str(page.find("li", attrs = {'class':'inline t-24 t-black t-normal break-words'}).text).strip()
            except:
                title = 'None'
            try:
                heading = str(page.find('h2', attrs = {'class':'mt1 t-18 t-black t-normal'}).text).strip()
            except:
                heading = 'None'
            try:
                loc = str(page.find('li', attrs = {'class':'t-16 t-black t-normal inline-block'}).text).strip()
            except:
                loc = 'None'     
            worksheet.write(i-1,0,profile_url)   
            worksheet.write(i-1,1,title)
            worksheet.write(i-1,2,heading)
            worksheet.write(i-1,3,loc)
        workbook.close()
            #data.append({'profile_url':profile_url,'title':title,'heading':heading,'loc':loc,})          

            
            
    def writeData(self):
        workbook = xlsxwriter.Workbook("linkedin.xlsx")
        worksheet = workbook.add_worksheet('Peoples')
        bold = workbook.add_format({'bold': True})
        worksheet.write(0,0,'profile_url',bold)
        worksheet.write(0,1,'Name',bold)
        worksheet.write(0,2,'heading',bold)
        worksheet.write(0,3,'location',bold)

        for i in range(0,len(data)+1):
           
            try:
                worksheet.write(i,0,data[i]['profile_url'])
            except:
                pass
            try:
                worksheet.write(i,1,data[i]['title'])
            except:
                pass
            try:
                worksheet.write(i,2,data[i]['heading'])
            except:
                pass
            try:
                worksheet.write(i,3,data[i]['loc'])
            except:
                pass
            
        workbook.close()
                     
    
    def start(self):
        self.getData()
    #   self.writeData()

# %%
workbook = xlsxwriter.Workbook("linkedin-search-data.xlsx")
worksheet = workbook.add_worksheet('Peoples')
bold = workbook.add_format({'bold': True})
worksheet.write(0,0,'profile_url',bold)
worksheet.write(0,1,'Name',bold)
worksheet.write(0,2,'heading',bold)
worksheet.write(0,3,'location',bold)
# Out:
# 0

# %%
class Linkedin():            
    def getData(self):
        
        #-----------------Linkedin Login------------------------------
        options = webdriver.ChromeOptions()
        options.add_argument("--disable-popup-blocking");
        driver = webdriver.Chrome('/usr/bin/chromedriver',options=options)
        #-----------------acces to profile page ------------------------
               #------------get data from sheet ---------
        raw_data= xlrd.open_workbook("last.xlsx").sheet_by_index(1)
        
               #-------------open a workbook for data writing --------------
        file = 'der.xlsx'
        wb = openpyxl.load_workbook(filename=file)
        ws = wb.get_sheet_by_name('Sheet1')
        L=pd.read_csv('export.csv')
        count=0
        t=time.time()
        List=['YES1','YES 2','YES 3']
        for i in range(708,725):
        #------------generate random action---------------      
        #---------------Only yes-------------------------
        #if (raw_data.cell_value(i, 3) in List):
            #--------------than sleep a bit--------------------
            time.sleep(1)
            #company=raw_data.cell_value(i, 25)
            #lastname=raw_data.cell_value(i, 26)
            #firstname=raw_data.cell_value(i, 27)
            driver.set_page_load_timeout(20)
            try:
                time.sleep(1)
                driver.get('https://www.google.com')
                driver.maximize_window()
                try:
                    driver.find_elements_by_xpath('//*[@id="t"]')[0].click()
                except:
                    pass
            except:
                pass

            time.sleep(1)
            search = raw_data.cell_value(i,7)
            print(search)
            #search = firstname+' '+lastname+' '+company+' '+'Linkedin'
            #search = "site:linkedin.com/in/ AND \"{}\" AND \"{}\"".format(firstname+' '+lastname, company)
            search_query = driver.find_elements_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[1]/div/div[2]/input')[0]
            #search_query = driver.find_element_by_name('q')
            search_query.send_keys(search)

            time.sleep(1)
            try:
                try:
                    driver.find_elements_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[3]/center/input[1]')[0].click()
                    time.sleep(2)
                except:
                    search_query.send_keys(Keys.RETURN)
                    time.sleep(2)
                try:
                    driver.find_elements_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[3]/center/input[1]')[0].click()
                    search_query.send_keys(Keys.RETURN)
                    time.sleep(2)
                except:
                    try:
                        driver.find_elements_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[3]/center/input[1]')[0].click()
                        search_query.send_keys(Keys.RETURN)
                        time.sleep(2)
                    except:
                        pass
            except:
                pass

            try:  
                linkedin_url = driver.find_elements_by_xpath('/html/body/div[7]/div[3]/div[10]/div[1]/div[2]/div/div[2]/div[2]/div/div/div[1]/div/div[1]/div/div/div[1]/a[1]')[0]
                #linkedin_url = driver.find_elements_by_xpath('//*[@id="main"]/div[3]/div/div[1]/a/div[1]')[0]
                linkedin_url.click()
                try:
                    linkedin_url.click()
                except:
                    pass
            except:

                #title = raw_data.cell_value(i, 26)+raw_data.cell_value(i, 27)
                heading = 'Not found'
                loc = 'Not found'
                #ws.cell(i+1,7,title)
                a=(int(raw_data.cell_value(i,0))+2)
                b=(int(raw_data.cell_value(i,0))+2)
                ws.cell(a,10,title)
                ws.cell(b,11,heading)
                wb.save(file)
                continue

            # #********** Profile Details **************#
            page = BeautifulSoup(driver.page_source,'lxml')
            try:
                title = str(page.find("h1", attrs = {'class':'top-card-layout__title'}).text).strip()
            except:
                title = 'None'
            try:
                heading = str(page.find('h2', attrs = {'class':'top-card-layout__headline'}).text).strip()
            except:
                heading = 'None'
            try:
                loc = str(page.find('span', attrs = {'class':'top-card__subline-item'}).text).strip()
            except:
                loc = 'None'  
            a=(int(raw_data.cell_value(i,0))+2)
            b=(int(raw_data.cell_value(i,0))+2)
            c=(int(raw_data.cell_value(i,0))+2)
            ws.cell(a,9,title)
            ws.cell(b,10,heading)
            ws.cell(c,11,loc)  
            wb.save(file)
            count+=1
            print(i)
            print(count)
            print('elapsed time is ',str(time.time()-t))

        #else:

            #ws.cell(i+1,9,'not a priority') 
            #wb.save(file)



            #data.append({'profile_url':profile_url,'title':title,'heading':heading,'loc':loc,})          


        
    def writeData(self):
        workbook = xlsxwriter.Workbook("linkedin.xlsx")
        worksheet = workbook.add_worksheet('Peoples')
        bold = workbook.add_format({'bold': True})
        worksheet.write(0,0,'profile_url',bold)
        worksheet.write(0,1,'Name',bold)
        worksheet.write(0,2,'heading',bold)
        worksheet.write(0,3,'location',bold)

 
    def start(self):
        self.getData()
    #   self.writeData()

# %%
Linkedin().start()
# Out:
# /home/zied/.local/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   from ipykernel import kernelapp as app
# Ashley Walker ICON plc Linkedin
# 708
# 1
# elapsed time is  10.744637727737427
# Josh John Boehringer Ingelheim Internaltional Linkedin
# 709
# 2
# elapsed time is  21.389322757720947
# Kevin Whelan Johnson & Johnson Linkedin
# 710
# 3
# elapsed time is  30.846279859542847
# Kristen Rall Galvani Bioelectronics Linkedin
# 711
# 4
# elapsed time is  40.20857357978821
# Pavan Battiprolu Rocket Pharmaceuticals Linkedin
# 712
# 5
# elapsed time is  49.977957010269165
# Vineet Kumar Dr. Reddy's Laboratories Linkedin
# 713
# 6
# elapsed time is  59.58886694908142
# Noelle Dettore IQVIA Inc Linkedin
# 714
# 7
# elapsed time is  70.06782746315002
# Christine Guindon Bausch Health Linkedin
# 715
# 8
# elapsed time is  79.67281866073608
# Eve Conrad PPD Linkedin
# 716
# 9
# elapsed time is  89.32411670684814
# Guy Robertson Walgreens Boots Linkedin
# 717
# 10
# elapsed time is  99.26591467857361
# Jeffrey Dietz GSK Linkedin
# 718
# 11
# elapsed time is  108.47697567939758
# Joyce Davis Pacira Pharmaceuticals Linkedin
# 719
# 12
# elapsed time is  118.35160827636719
# Stacey Persky Steris Linkedin
# 720
# 13
# elapsed time is  128.14868664741516
# James Sims Akebia Therapeutics Linkedin
# 721
# 14
# elapsed time is  137.72813415527344
# Roy Brown Curium Linkedin
# 722
# 15
# elapsed time is  147.27992248535156
# Traci Camacho Covance Linkedin
# 723
# 16
# elapsed time is  156.64258408546448
# Erin Cosgrove Oxford Immunotec Linkedin
# 724
# 17
# elapsed time is  166.38241696357727

# %%
rn=randint(1,9)
            if (rn==1):
                driver.get('https://www.yahoo.fr')
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    pass
            elif (rn==2):
                driver.get('https://www.amazon.fr')
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            elif (rn==3):
                driver.get('https://www.python.org')
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    pass

            elif (rn==4):
                driver.get('https://www.stackoverflow.com')
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            elif (rn==5):
                driver.get('https://www.sfr.fr')
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            elif (rn==6):
                driver.get('https://www.micromania.org')
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    pass

            elif (rn==7):
                driver.get('https://www.fnac.com')
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    pass

            elif (rn==8):
                driver.get('https://www.microsoft.com')
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    pass

            elif (rn==9):
                driver.get('https://www.apple.com')
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                try:
                    links = driver.find_elements_by_partial_link_text('')
                    l = links[randint(0, len(links)-1)]
                    l.click()
                except:
                    pass

# %%
 rn=randint(1,len(L)-1)
            driver.get('https://www.'+L[rn]+'.com')
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            try:
                links = driver.find_elements_by_partial_link_text('')
                l = links[randint(0, len(links)-1)]
                l.click()
            except:
                pass
            #--------------than sleep a bit--------------------
            time.sleep(4)

# %%
workbook = xlsxwriter.Workbook("linkedin-search-data.xlsx")
        worksheet = workbook.add_worksheet('Peoples')
        bold = workbook.add_format({'bold': True})
        worksheet.write(0,1,'Name',bold)
        worksheet.write(0,2,'heading',bold)
        worksheet.write(0,3,'location',bold)
        workbook.close()

# %%
import pandas as pd

# %%
sites=pd.read_csv('news.csv')

# %%
sites['source_url'][0]
# Out:
# 'https://www.24h.com.vn/bong-da/u23-viet-nam-vao-tu-ket-hlv-bahrain-to-trong-tai-bat-sai-khen-van-quyet-c48a985098.html'

# %%
sites=sites['source_url'][:1000]

# %%
sites.to_csv(('export.csv'))
# Out:
# /home/zied/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
sites=pd.read_csv('export.csv')

# %%
sites['https://www.24h.com.vn/bong-da/u23-viet-nam-vao-tu-ket-hlv-bahrain-to-trong-tai-bat-sai-khen-van-quyet-c48a985098.html']
# Out:
# 0      https://www.aftenposten.no/norge/i/m6joJq/Berg...
# 1                    http://www.albawabhnews.com/3241511
# 2                    http://www.albawabhnews.com/3245292
# 3                    http://www.albawabhnews.com/3249336
# 4                    http://www.albawabhnews.com/3249342
#                              ...
# 994    https://www.rfa.org/english/news/cambodia/rele...
# 995    https://www.rtl.fr/actu/conso/le-poisson-veut-...
# 996    https://www.rtl.fr/actu/insolite/lyon-ils-deco...
# 997    https://skateboarding.transworld.net/videos/sp...
# 998    https://www.sovsport.ru/football/news/1070166-...
# Name: https://www.24h.com.vn/bong-da/u23-viet-nam-vao-tu-ket-hlv-bahrain-to-trong-tai-bat-sai-khen-van-quyet-c48a985098.html, Length: 999, dtype: object

# %%
options = Options()
        #options.add_argument("headless")
        ua= UserAgent()
        a=ua.random
        options.add_argument('user-agent={a}')

# %%
driver = webdriver.Chrome('/usr/bin/chromedriver')
driver.get('http://www.google.fr')

# %%
search_query = driver.find_elements_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[1]/div/div[2]/input')[0]
search_query.send_keys('hey')

driver.find_elements_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[3]/center/input[1]')[0].click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-11-b7bef01722cd> in <module>
#       2 search_query.send_keys('hey')
#       3
# ----> 4 driver.find_elements_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[3]/center/input[1]')[0].click()
#
# ~/.local/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/.local/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.local/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <input class="gNO89b" value="Recherche Google" aria-label="Recherche Google" name="btnK" type="submit" data-ved="0ahUKEwilhrnGsIjnAhWr6uAKHaDOAhkQ4dUDCAo"> is not clickable at point (439, 369). Other element would receive the click: <span>...</span>
#   (Session info: chrome=79.0.3945.88)

# %%
rn=randint(1,len(L)-1)
                try:
                    driver.set_page_load_timeout(8)
                    driver.get(L['https://www.24h.com.vn/bong-da/u23-viet-nam-vao-tu-ket-hlv-bahrain-to-trong-tai-bat-sai-khen-van-quyet-c48a985098.html'][rn])

                    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                except TimeoutException as ex:
                    pass

# %%
            except TimeoutException as ex:
                try:
                    time.sleep(2)
                    driver.get('https://www.google.com')
                    driver.maximize_window()
                    try:
                        time.sleep(2)
                        driver.find_elements_by_xpath('//*[@id="t"]')[0].click()
                    except:
                        pass
                except TimeoutException as ex:
                    time.sleep(2)
                    driver.get('https://www.google.com')
                    driver.maximize_window()
                    try:
                        time.sleep(2)
                        driver.find_elements_by_xpath('//*[@id="t"]')[0].click()
                    except:
                        pass
